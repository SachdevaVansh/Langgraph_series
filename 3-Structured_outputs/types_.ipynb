# %%
from pydantic import BaseModel, Field 
from euriai.langchain import EuriaiChatModel

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = EuriaiChatModel(
    api_key=os.getenv("EURI_API_KEY"),
    model="gpt-4.1-nano"
)

# %%
class Country(BaseModel):
    """ Information about a country"""

    name: str=Field(description="name of the country")
    language:str=Field(description="language of the country")
    capital:str=Field(description="Capital of the Country")

structured_llm=llm.with_structured_output(Country)
structured_llm
# Out:
# EuriaiStructuredChatModel(api_key='euri-dbb5dcbdafdd3ab20169f879f04ec618071930a3f3a69fffa13bfa25fc5c7076')

# %%
structured_llm.invoke("Tell me about India")
# Out:
# c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\pydantic\v1\main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# Country(name='India', language='Hindi', capital='New Delhi')

# %%
from typing_extensions import Annotated, TypedDict
from typing import Optional


# TypedDict
class Joke(TypedDict):
    """Joke to tell user."""

    setup: Annotated[str, ..., "The setup of the joke"]

    # Alternatively, we could have specified setup as:

    # setup: str                    # no default, no description
    # setup: Annotated[str, ...]    # no default, no description
    # setup: Annotated[str, "foo"]  # default, no description

    punchline: Annotated[str, ..., "The punchline of the joke"]
    rating: Annotated[Optional[int], None, "How funny the joke is, from 1 to 10"]


structured_llm = llm.with_structured_output(Joke)

structured_llm.invoke("Tell me a joke about cats")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 23
#      18     rating: Annotated[Optional[int], None, "How funny the joke is, from 1 to 10"]
#      21 structured_llm = llm.with_structured_output(Joke)
# ---> 23 structured_llm.invoke("Tell me a joke about cats")
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\euriai\langchain.py:610, in EuriaiStructuredChatModel.invoke(self, input, config, **kwargs)
#     608 """Invoke the model and return structured output."""
#     609 # Get the regular AI message response
# --> 610 response = super().invoke(input, config, **kwargs)
#     612 # Parse the response content into structured format
#     613 structured_result = self._parse_structured_response(response.content)
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)    390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1025, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1016 @override
#    1017 def generate_prompt(
#    1018     self,
#    (...)   1022     **kwargs: Any,
#    1023 ) -> LLMResult:
#    1024     prompt_messages = [p.to_messages() for p in prompts]
# -> 1025     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\langchain_core\language_models\chat_models.py:842, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     839 for i, m in enumerate(input_messages):
#     840     try:
#     841         results.append(
# --> 842             self._generate_with_cache(
#     843                 m,
#     844                 stop=stop,
#     845                 run_manager=run_managers[i] if run_managers else None,
#     846                 **kwargs,
#     847             )
#     848         )
#     849     except BaseException as e:
#     850         if run_managers:
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1091, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1089     result = generate_from_stream(iter(chunks))
#    1090 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1091     result = self._generate(
#    1092         messages, stop=stop, run_manager=run_manager, **kwargs
#    1093     )
#    1094 else:
#    1095     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\euriai\langchain.py:295, in EuriaiChatModel._generate(self, messages, stop, run_manager, **kwargs)
#     293 """Generate chat response."""
#     294 # Convert messages to prompt format
# --> 295 prompt = self._messages_to_prompt(messages)
#     297 # Prepare request
#     298 request_params = {
#     299     "prompt": prompt,
#     300     "temperature": self.temperature,
#     301     "max_tokens": self.max_tokens,
#     302 }
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\euriai\langchain.py:605, in EuriaiStructuredChatModel._messages_to_prompt(self, messages)
#     602 original_prompt = super()._messages_to_prompt(messages)
#     604 # Add structured output instructions
# --> 605 return self._create_structured_prompt(original_prompt)
#
# File c:\Users\vansh\Desktop\Langgraph_Youtube\langgrap_venv\Lib\site-packages\euriai\langchain.py:548, in EuriaiStructuredChatModel._create_structured_prompt(self, original_prompt)
#     541         """Create a prompt that requests structured JSON output."""
#     542         json_schema = self._get_json_schema()
#     544         structured_prompt = f"""{original_prompt}
#     545
#     546 Please respond with a valid JSON object that matches this exact schema:
#     547 ```json
# --> 548 {json.dumps(json_schema, indent=2)}
#     549 ```
#     550
#     551 Your response must be valid JSON that can be parsed. Do not include any other text outside the JSON object."""
#     553         return structured_prompt
#
# File ~\Anaconda3\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\Anaconda3\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~\Anaconda3\Lib\json\encoder.py:261, in JSONEncoder.iterencode(self, o, _one_shot)
#     256 else:
#     257     _iterencode = _make_iterencode(
#     258         markers, self.default, _encoder, indent, floatstr,
#     259         self.key_separator, self.item_separator, self.sort_keys,
#     260         self.skipkeys, _one_shot)
# --> 261 return _iterencode(o, 0)
#
# File ~\Anaconda3\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type _TypedDictMeta is not JSON serializable

# %%
## Defining a json schema 
json_schema={
    "title":"joke",
    "description": "Joke to tell user.",
    "type": "object",
    "properties": {
        "setup": {
            "type": "string",
            "description": "The setup of the joke",
        },
        "punchline": {
            "type": "string",
            "description": "The punchline to the joke",
        },
        "rating": {
            "type": "integer",
            "description": "How funny the joke is, from 1 to 10",
            "default": None,
        },
    },
    "required":["setup","punchline"]
}

structured_llm=llm.with_structured_output(json_schema)

structured_llm.invoke("Tell me a joke about cats")
# Out:
# {'setup': 'Why did the cat sit on the computer?',
#  'punchline': 'Because it wanted to keep an eye on the mouse!',
#  'rating': 7}
